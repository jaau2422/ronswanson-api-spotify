# %%
import spotipy
import pandas as pd
import json
import webbrowser
import urllib.request
import spotipy.util as util
import nltk
from nltk.corpus import stopwords
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
from spotipy.oauth2 import SpotifyClientCredentials
import json

# %%
# open file with keys and set the path to your credentials JSON file
credentials = "spotify_keys.json"
with open(credentials, "r") as keys:
    api_tokens = json.load(keys)

# %%
# read the keys and assign each to a variable
client_id = api_tokens["client_id"]
client_secret = api_tokens["client_secret"]

# %%
client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)

# %%
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# learn about more query strings for spotify here: https://developer.spotify.com/documentation/web-api/reference/#/operations/search
track_results = sp.search(q='year:2022', type='track', limit=50)

# %%
print(track_results)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=year%3A2022&type=track&offset=0&limit=50', 'items': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'}, 'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4', 'id': '3TVXtAsR1Inumwj472S9r4', 'name': 'Drake', 'type': 'artist', 'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/1URnnhqYAYcrqrcwql10ft'}, 'href': 'https://api.spotify.com/v1/artists/1URnnhqYAYcrqrcwql10ft', 'id': '1URnnhqYAYcrqrcwql10ft', 'name': '21 Savage', 'type': 'artist', 'uri': 'spotify:artist:1URnnhqYAYcrqrcwql10ft'}], 'available_markets': ['AD', 'AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO',
# ...

# %%
tracks = track_results['tracks']['items']

# %%
songlist=[]
for song in tracks:
    print(song['name'])
    songlist.append(song['name'])
# Out:
# Rich Flex
# Anti-Hero
# Unholy (feat. Kim Petras)
# Romantic Homicide
# Something in the Orange
# Major Distribution
# Bad Habit
# Just Wanna Rock
# Pussy & Millions (feat. Travis Scott)
# Jimmy Cooks (feat. 21 Savage)
# Tití Me Preguntó
# Lavender Haze
# Me Porto Bonito
# On BS
# Midnight Rain
# You Proof
# Spin Bout U
# Shirt
# I'm Good (Blue)
# I Ain't Worried
# Anti-Hero
# Circo Loco
# Maroon
# Privileged Rappers
# WAIT FOR U (feat. Drake & Tems)
# Snow On The Beach (feat. Lana Del Rey)
# Bad Habit
# Would've, Could've, Should've
# Karma
# Die For You
# You're On Your Own, Kid
# Broke Boys
# Midnight Rain
# I Like You (A Happier Song) (with Doja Cat)
# Maroon
# Lavender Haze
# BackOutsideBoyz
# You're On Your Own, Kid
# Karma
# Bejeweled
# CUFF IT
# As It Was
# golden hour
# Efecto
# Bejeweled
# Made You Look
# The Great War
# Evergreen (You Didn’t Deserve Me At All)
# Late Night Talking
# Vigilante Shit

# %%
lower_songlist = [x.lower() for x in songlist]

# %%
modified_songlist = []
for x in songlist:
    songtitle=[]
    for i in x.lower().split(' '):
        if i not in stopwords.words('english'):
            songtitle.append(i)
    modified_songlist.append(' '.join(songtitle))
print(modified_songlist)
# Out:
# ['rich flex', 'anti-hero', 'unholy (feat. kim petras)', 'romantic homicide', 'something orange', 'major distribution', 'bad habit', 'wanna rock', 'pussy & millions (feat. travis scott)', 'jimmy cooks (feat. 21 savage)', 'tití preguntó', 'lavender haze', 'porto bonito', 'bs', 'midnight rain', 'proof', 'spin bout u', 'shirt', "i'm good (blue)", "ain't worried", 'anti-hero', 'circo loco', 'maroon', 'privileged rappers', 'wait u (feat. drake & tems)', 'snow beach (feat. lana del rey)', 'bad habit', "would've, could've,", 'karma', 'die', 'own, kid', 'broke boys', 'midnight rain', 'like (a happier song) (with doja cat)', 'maroon', 'lavender haze', 'backoutsideboyz', 'own, kid', 'karma', 'bejeweled', 'cuff', '', 'golden hour', 'efecto', 'bejeweled', 'made look', 'great war', 'evergreen (you didn’t deserve all)', 'late night talking', 'vigilante shit']

# %%
var=modified_songlist[0]
newvar= var.split(' ')
newvar2 = newvar[0]

# %%
url = ("https://ron-swanson-quotes.herokuapp.com/v2/quotes/search/"+ newvar2)
request = urllib.request.Request(url)
response = urllib.request.urlopen(request)

# %%
quote = json.loads(response.read())

# %%
print(quote)
# Out:
# ['Clear alcohols are for rich women on diets.']
